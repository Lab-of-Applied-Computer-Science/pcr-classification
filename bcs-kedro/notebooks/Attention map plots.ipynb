# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img3 = np.load('./bcs-kedro/data/03_primary/test-datasets-for-att-map/attention-maps/pcr/rigid_CASE0_0_attention_map.npz')
plt.imshow(img3['attmap'], cmap='jet')

# %%
img3 = np.load('./bcs-kedro/data/03_primary/test-datasets-for-att-map/attention-maps/pcr/rigid_CASE0_0_attention_map.npz')
plt.imshow(img3['attmap'], cmap='jet')

# %%
img4 = np.load('./bcs-kedro/data/03_primary/test-datasets-for-att-map/attention-maps/pcr/rigid_CASE0_0_attention_map.npz')
plt.imshow(img4['attmap'], cmap='jet')
